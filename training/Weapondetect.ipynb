# %%
! pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')


# !unzip /content/drive/MyDrive/Weapon_yolov8.zip -d /content/Weapon_yolov8/


# !ls /content/Weapon_yolov8/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/Weapon_yolov8/train/images/armas-2374-_jpg.rf.55e64864172d49fe00e1624fe3f617fa.jpg
#  extracting: /content/Weapon_yolov8/train/images/armas-2375-_jpg.rf.159abd7ccfda74735d031a72b6c44f4c.jpg
#  extracting: /content/Weapon_yolov8/train/images/armas-2376-_jpg.rf.6363d8f4b3d0de43bbbdaaa4224165f1.jpg
#  extracting: /content/Weapon_yolov8/train/images/armas-2377-_jpg.rf.3a68bbf8f80bcf90539bca9dbcc2cab4.jpg
#  extracting: /content/Weapon_yolov8/train/images/armas-2378-_jpg.rf.65fb60113794c80a510ee3ee2b77d65f.jpg
#  extracting: /content/Weapon_yolov8/train/images/armas-2379-_jpg.rf.4565f46ab95a577d1fef0ef89b098554.jpg
#  extracting: /content/Weapon_yolov8/train/images/armas-238-_jpg.rf.a5835cbf163e6b8519d548cd609e41a1.jpg
#  extracting: /content/Weapon_yolov8/train/images/armas-2380-_jpg.rf.702faf0a935ab6a27e77cfbe5bbe8aa1.jpg
# ...

# %%
# !ls /content/Weapon_yolov8/train/images | head -5
# !ls /content/Weapon_yolov8/train/labels | head -5
# Out:
# armas-1155-_jpg.rf.4fe30508d5ca251f1eb449a91674c3c4.jpg
# armas-1165-_jpg.rf.e5ef41a14bdf3e5d292cbd22e4f7dd27.jpg
# armas-1168-_jpg.rf.70ae9434bb37b70ec59889bdbf1cba6a.jpg
# armas-1171-_jpg.rf.ee696971716554639995912e032b163d.jpg
# armas-117-_jpg.rf.89eb89af267837c360679881065ead2c.jpg
# armas-1155-_jpg.rf.4fe30508d5ca251f1eb449a91674c3c4.txt
# armas-1165-_jpg.rf.e5ef41a14bdf3e5d292cbd22e4f7dd27.txt
# armas-1168-_jpg.rf.70ae9434bb37b70ec59889bdbf1cba6a.txt
# armas-1171-_jpg.rf.ee696971716554639995912e032b163d.txt
# armas-117-_jpg.rf.89eb89af267837c360679881065ead2c.txt

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
yaml_path = "/content/Weapon_yolov8/data.yaml"
with open(yaml_path, "w") as f:
    f.write(f"""
train: /content/Weapon_yolov8/train/images
val: /content/Weapon_yolov8/test/images
nc: 2
names: ['guns','knife']
""")

# %%
# !yolo detect train data="/content/Weapon_yolov8/data.yaml" model=yolov8n.pt epochs=50 imgsz=640 batch=16 \
project="/content/Weapon_yolov8_results" name="yolov8n_weapon"
# Out:
# ...
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/Weapon_yolov8_results/yolov8n_weapon/weights/best.pt /content/drive/MyDrive/
